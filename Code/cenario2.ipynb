# %% [markdown]
# # Todas as colunas e sem outliers

# %%
import pandas as pd
import matplotlib as mpl
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cenario1_engine.csv")

# %%
df.head()
# Out:
#   Brand_Mod               model  model_year      KM      fuel     HP  Litros  \
# 0     Outra      Wrangler Sport        2014  114263  Gasoline  285.0     3.6
# 1     Outra      Highlander XLE        2015  110361  Gasoline  270.0     3.5
# 2     Outra    Camry Hybrid XLE        2018  112076    Hybrid  208.0     2.5
# 3     Outra  Outback Touring XT        2021   53913  Gasoline  260.0     2.4
# 4     Outra         GX 460 Base        2018  120701  Gasoline  301.0     4.6
#
#    Cilindros transmission_mod ext_col_mod int_col_mod  \
# 0        6.0        Automatic       Outra       Black
# 1        6.0        Automatic       Outra       Outra
# 2        4.0              CVT       white       Black
# 3        4.0              CVT       Outra       Outra
# 4        8.0        Automatic       white       beige
#
#                              accident_mod clean_title_mod  price_eur
# 0                           None reported             Yes      20020
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3207 entries, 0 to 3206
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand_Mod         3207 non-null   object
#  1   model             3207 non-null   object
#  2   model_year        3207 non-null   int64
#  3   KM                3207 non-null   int64
#  4   fuel              3207 non-null   object
#  5   HP                2578 non-null   float64
#  6   Litros            2891 non-null   float64
#  7   Cilindros         2705 non-null   float64
#  8   transmission_mod  3207 non-null   object
#  9   ext_col_mod       3207 non-null   object
#  10  int_col_mod       3207 non-null   object
#  11  accident_mod      3207 non-null   object
#  12  clean_title_mod   3207 non-null   object
#  13  price_eur         3207 non-null   int64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 350.9+ KB

# %%
Q1 = df['model_year'].quantile(0.25)
Q3 = df['model_year'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# Filtrar DataFrame para remover outliers
df = df[df['model_year'] <= limite_superior]
df = df[df['model_year'] >= limite_inferior]

# Criar um boxplot com destaque para outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['model_year'], showfliers=True)
plt.title('Boxplot com Outliers')
plt.show()

# %%
Q1 = df['KM'].quantile(0.25)
Q3 = df['KM'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# Filtrar DataFrame para remover outliers
df = df[df['KM'] <= limite_superior]
df = df[df['KM'] >= limite_inferior]

# Criar um boxplot com destaque para outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['KM'], showfliers=True)
plt.title('Boxplot com Outliers')
plt.show()

# %%
Q1 = df['HP'].quantile(0.25)
Q3 = df['HP'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# Filtrar DataFrame para remover outliers
df = df[df['HP'] <= limite_superior]
df = df[df['HP'] >= limite_inferior]

# Criar um boxplot com destaque para outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['HP'], showfliers=True)
plt.title('Boxplot com Outliers')
plt.show()

# %%
# Criar um boxplot com destaque para outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Litros'], showfliers=True)
plt.title('Boxplot com Outliers')
plt.show()

# %%
Q1 = df['Litros'].quantile(0.25)
Q3 = df['Litros'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# Filtrar DataFrame para remover outliers
df = df[df['Litros'] <= limite_superior]
df = df[df['Litros'] >= limite_inferior]

# Criar um boxplot com destaque para outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Litros'], showfliers=True)
plt.title('Boxplot com Outliers')
plt.show()

# %%
Q1 = df['Cilindros'].quantile(0.25)
Q3 = df['Cilindros'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# Filtrar DataFrame para remover outliers
df = df[df['Cilindros'] <= limite_superior]
df = df[df['Cilindros'] >= limite_inferior]

# Criar um boxplot com destaque para outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Cilindros'], showfliers=True)
plt.title('Boxplot com Outliers')
plt.show()

# %%
Q1 = df['price_eur'].quantile(0.25)
Q3 = df['price_eur'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# Filtrar DataFrame para remover outliers
df = df[df['price_eur'] <= limite_superior]
df = df[df['price_eur'] >= limite_inferior]

# Criar um boxplot com destaque para outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['price_eur'], showfliers=True)
plt.title('Boxplot com Outliers')
plt.show()

# %%
df.head()
# Out:
#   Brand_Mod               model  model_year      KM      fuel     HP  Litros  \
# 0     Outra      Wrangler Sport        2014  114263  Gasoline  285.0     3.6
# 1     Outra      Highlander XLE        2015  110361  Gasoline  270.0     3.5
# 2     Outra    Camry Hybrid XLE        2018  112076    Hybrid  208.0     2.5
# 3     Outra  Outback Touring XT        2021   53913  Gasoline  260.0     2.4
# 4     Outra         GX 460 Base        2018  120701  Gasoline  301.0     4.6
#
#    Cilindros transmission_mod ext_col_mod int_col_mod  \
# 0        6.0        Automatic       Outra       Black
# 1        6.0        Automatic       Outra       Outra
# 2        4.0              CVT       white       Black
# 3        4.0              CVT       Outra       Outra
# 4        8.0        Automatic       white       beige
#
#                              accident_mod clean_title_mod  price_eur
# 0                           None reported             Yes      20020
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2217 entries, 0 to 3206
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand_Mod         2217 non-null   object
#  1   model             2217 non-null   object
#  2   model_year        2217 non-null   int64
#  3   KM                2217 non-null   int64
#  4   fuel              2217 non-null   object
#  5   HP                2217 non-null   float64
#  6   Litros            2217 non-null   float64
#  7   Cilindros         2217 non-null   float64
#  8   transmission_mod  2217 non-null   object
#  9   ext_col_mod       2217 non-null   object
#  10  int_col_mod       2217 non-null   object
#  11  accident_mod      2217 non-null   object
#  12  clean_title_mod   2217 non-null   object
#  13  price_eur         2217 non-null   int64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 259.8+ KB

# %%
df.to_csv("cenario2_engine.csv", index=False)

# %%
df_final = pd.read_csv("cenario2_engine.csv")

# %%
# Seleciona apenas as colunas não numéricas
categorical_columns = df_final.select_dtypes(include='object').columns

# Mapeia as categorias para números
for column in categorical_columns:
    df_final[column] = df_final[column].astype('category').cat.codes

# Calcule a matriz de correlação de Spearman
correlation_matrix = df_final.corr(method='spearman')

# Visualize a matriz de correlação usando um heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', fmt=".2f")
plt.title('Matriz de Correlação')
plt.show()
